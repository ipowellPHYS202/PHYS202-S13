# %%
import numpy.random
numpy.random?

# %%
#print 5 uniformly distributed numbers between 0 and 1
print numpy.random.random(5)
#print another 5-should be different
print numpy.random.random(5)
# Out:
# [ 0.3254995   0.41271463  0.82658526  0.06576661  0.54725512]
# [ 0.40374895  0.31977846  0.81240545  0.69805062  0.96417925]

# %%
#now set the seed to something:
numpy.random.seed(4242)
print "Using seed = 4242:"
print numpy.random.random(5)
# Out:
# Using seed = 4242:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#restore seed to none:
numpy.random.seed(None)

#print 5 morenumbers using the next random seed
print "Using seed = None:"
print numpy.random.random(5)
# Out:
# Using seed = None:
# [ 0.66982806  0.60823793  0.61832742  0.52524745  0.9636762 ]

# %%
#reset seed to 4242:
numpy.random.seed(4242)
print numpy.random.random(5)
# Out:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#these are the same numbers as before!

# %%
#reset the seed
numpy.random.seed(None)
z = numpy.random.random(100000)
hist(z,100,normed=True)
plot([0,1.],[1.,1.],'r-',lw=3)
xlabel('x', fontsize = 20)
ylabel('sample probability', fontsize=20)
show()

# %% [markdown]
# ###Example 1: Analytix Inverse CDF Transfrom

# %%
x = arange(0.,pi+.01,.01)
f = lambda x: sin(x)/2.
F = lambda x: (cos(0)-cos(x))/2.
    
plot(x,f(x), label = 'True distribution',lw=3)
plot(x,F(x), label = 'Cumulative function',lw=3)
    
xlim(0,3.5)
ylim(0,1.1)

legend(loc=0)
show()

# %%
#number of samples
N=10000

#N random numbers between 0 and 1
z=numpy.random.random_sample(N);

#Inverse CDF
Finv = lambda z: arccos(cos(0)-2*z)

#sampled x values
xsamples = Finv(z);

#how do they compare to the original?
hist(xsamples,50,normed=True,label="sampled distribution")
plot(x,f(x),label="True distribution", lw=3,color='red')

xlim(0,pi)
ylim(0,.7)
legend(loc=0)
show()

# %%
hist?

# %% [markdown]
# ###Exercise 1: Exponential Function - Analytic

# %%
lamb = 1
f = lambda x: lamb*e**(-lamb*x)

# %%
CDF = lambda x: -e**(-lamb*x)+1

z = numpy.random.random_sample(N)
Finv = lambda z: (1/lamb)*log(1/(1-z))

x_samples = Finv(z);

plot(x,CDF(x), label = "CDF")
plot(x,f(x), label = "Function")
legend(loc=0)
show()

# %%
x_samples = Finv(z);
hist(x_samples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label = "True Distribution", lw=3,color='red')
legend(loc=0)
show()

# %% [markdown]
# ###Exercise 2: Exponential Function -Numerical

# %%
cumsum?
from scipy import integrate

# %%
searchsorted?

# %%
searchsorted([1,2,3,5], 4)
# Out:
# 3

# %%
lamb=1

dx = .1
x = arange(0.,8.,dx)
f = lambda x: lamb*e**(-lamb*x)
CDF=zeros(x.shape)
CDF=cumsum(f(x))/sum(f(x))

# %%
N = 10000
z = numpy.random.random_sample(N)

z_i=1

print CDF.searchsorted(z_i)
x_i = CDF.searchsorted(1)*dx+.1
print x_i
# Out:
# 79
# 8.0

# %%
x_i= (CDF.searchsorted(1)*dx+.1)
print x_i

def Finv(z):
    A=[]
    for i in z:
        A.append(CDF.searchsorted(i)*dx+.1)
    return A
        
X_samples=Finv(z)
# Out:
# 8.0

# %%
plot(x,f(x))
plot(x,CDF)
plot(x,f(x), label='true distribution')
hist(X_samples,50,normed=True)
xlim(0,8)
show()

# %% [markdown]
# ###Exercise 3: Quantum Double Slit Experiment
