],[ 0.59    ,    0.69367232 , 0.40926667],[ 0.6    ,     0.66511111 , 0.39906667],[ 0.61    ,    0.63857923 , 0.38953333],[ 0.62    ,    0.61225806 , 0.3796    ],[ 0.63    ,    0.58486772 , 0.36846667],[ 0.64    ,    0.56052083 , 0.35873333],[ 0.65    ,    0.53723077 , 0.3492    ],[ 0.66    ,    0.51444444 , 0.33953333],[ 0.67    ,    0.49104478 , 0.329     ],[ 0.68    ,    0.47     ,   0.3196    ],[ 0.69    ,    0.44772947 , 0.30893333],[ 0.7   ,      0.42742857 , 0.2992    ],[ 0.71   ,     0.40826291 , 0.28986667],[ 0.72   ,     0.38796296 , 0.27933333],[ 0.73   ,     0.36940639 , 0.26966667],[ 0.74   ,     0.35063063,  0.25946667],[ 0.75   ,     0.33288889,  0.24966667],[ 0.76   ,     0.31535088 , 0.23966667],[ 0.77   ,     0.29792208 , 0.2294    ],[ 0.78   ,     0.28179487 , 0.2198    ],[ 0.79   ,     0.26540084 , 0.20966667],[ 0.8    ,     0.24966667 , 0.19973333]])

# %%
#Denisty Plots
plot(CA184Data[:,[0]],CA184Data[:,[1]],'k',lw=1.5,label='Average Velocity')
plot(CA184Data[:,[0]],CA184Data[:,[2]],'b',lw=1.5,label='Average Current')
xlabel('Density (cars/Length)')
xlim(.02,.8)
title("CA184 Current/Average Velocity vs. Density")
legend(loc=0)
show()

# %% [markdown]
# ###Analysis:  Here I set the max speed to v_max = 10.  There seems to be a phase shift at a density around ~0.10 (i.e. 10 cars on a road 100 car-lengths long) where the cars go from having an increasing current and stable average velocity to an exponentially decreasing average velocity and a linearly decreasing current.  The relationship between current and average velocity is interesting in this way.  Also, by changing v_max to be greater, the phase transition becomes much less abrupt as depicted in the next plots.

# %%
fasterCA184Data=array([[  0.02    ,    19.76666667 ,  0.39533333],[  0.03    ,    19.11777778 ,  0.57353333],[  0.04    ,    19.05666667 ,  0.76226667],[  0.05    ,    18.03733333 ,  0.90186667],[  0.06    ,    14.91444444 ,  0.89486667],[  0.07    ,    12.88952381 ,  0.90226667],[  0.08    ,    11.1375    ,   0.891     ],[  0.09    ,     9.78666667,   0.8808    ],[  0.1     ,     8.80666667,   0.88066667],[  0.11    ,     7.83939394,   0.86233333],[  0.12    ,     7.14388889,   0.85726667],[  0.13    ,     6.58461538,   0.856     ],[  0.14    ,     5.99666667,   0.83953333],[  0.15    ,     5.61288889,   0.84193333],[  0.16    ,     5.15125   ,   0.8242    ],[  0.17    ,     4.79764706,   0.8156    ],[  0.18    ,     4.48333333,   0.807     ],[  0.19    ,     4.18      ,   0.7942    ],[  0.2     ,     3.93866667,   0.78773333],[  0.21    ,     3.71587302,   0.78033333],[  0.22    ,     3.51787879,   0.77393333],[  0.23    ,     3.30347826,   0.7598    ],[  0.24    ,     3.13138889 ,  0.75153333],[  0.25    ,     2.96853333 ,  0.74213333],[  0.26    ,     2.82333333 ,  0.73406667],[  0.27    ,     2.67604938 ,  0.72253333],[  0.28    ,     2.55428571 ,  0.7152    ],[  0.29    ,     2.54833333 ,  0.71353333],[  0.3     ,     2.31422222,   0.69426667],[  0.31    ,     2.20731183,   0.68426667],[  0.32    ,     2.10708333,   0.67426667],[  0.33    ,     2.01353535 ,  0.66446667],[  0.34    ,     1.93196078,   0.65686667],[  0.35     ,    1.83714286 ,  0.643     ],[  0.36    ,     1.77037037 ,  0.63733333],[  0.37    ,     1.69243243 ,  0.6262    ],[  0.38    ,     1.62280702 ,  0.61666667],[  0.39    ,     1.55589744 ,  0.6068    ],[  0.4     ,     1.48916667 ,  0.59566667],[  0.41    ,     1.43219512 ,  0.5872    ],[  0.42    ,     1.37539683 ,  0.57766667],[  0.43    ,     1.3179845  ,  0.56673333],[  0.44    ,     1.26818182 ,  0.558     ],[  0.45    ,     1.21748148 ,  0.54786667],[  0.46    ,     1.16782609,   0.5372    ],[  0.47    ,     1.1212766 ,   0.527     ],[  0.48    ,     1.07958333 ,  0.5182    ],[  0.49    ,     1.03632653,   0.5078    ],[  0.5     ,     0.99653333,   0.49826667],[  0.51    ,     0.95490196 ,  0.487     ],[  0.52    ,     0.91961538 ,  0.4782    ],[  0.53    ,     0.88415094 ,  0.4686    ],[  0.54    ,     0.84839506 ,  0.45813333],[  0.55    ,     0.81624242,   0.44893333],[  0.56    ,     0.78380952 ,  0.43893333],[  0.57    ,     0.75251462 ,  0.42893333],[  0.58    ,     0.75251462,   0.42893333],[  0.59    ,     0.69299435 ,  0.40886667],[  0.6     ,     0.66466667 ,  0.3988    ]])

# %%
#A comparison
plot(fasterCA184Data[:,[0]],fasterCA184Data[:,[1]],'g',lw=1.5,label='Average Velocity (v_max=20)')
plot(fasterCA184Data[:,[0]],fasterCA184Data[:,[2]],'b',lw=1.5,label='Average Current (v_max=20)')
plot(CA184Data[:,[0]],CA184Data[:,[1]],'k--',lw=1.5,label='Average Velocity (v_max=10)')
plot(CA184Data[:,[0]],CA184Data[:,[2]],'r--',lw=1.5,label='Average Current (v_max=10)')
xlabel('Density (cars/Length)')
xlim(.02,.6)
title("CA184: Comparing Max Velocities")
legend(loc=0)
show()

# %% [markdown]
# ###Notice that not only does the simulation with the higher v_max have a more gradual phase transition but also that the plots are out of sync until the critical density for phase transition of ~0.10 where they completely match up!

# %%
#Copying and Pasting the Data from the STCA simulation:
STCAData=array([[ 0.02    ,    9.66   ,     0.1932    ],[ 0.03    ,    9.57333333 , 0.2872    ],[ 0.04    ,    9.55166667 , 0.38206667],[ 0.05    ,    9.35733333 , 0.46786667],[ 0.06    ,    9.57555556 , 0.57453333],[ 0.07    ,    9.25809524 , 0.64806667],[ 0.08    ,    8.4125     , 0.673     ],[ 0.09    ,    8.04074074 , 0.72366667],[ 0.1     ,    5.954      , 0.5954    ],[ 0.11    ,    5.27454545 , 0.5802    ],[ 0.12    ,    4.60277778 , 0.55233333],[ 0.13    ,    4.
# %%
#Density Plots
plot(STCAData[:,[0]],STCAData[:,[1]],'k',lw=1.5,label='Average Velocity')
plot(STCAData[:,[0]],STCAData[:,[2]],'b',lw=1.5,label='Average Current')
xlabel('Density (cars/Length)')
xlim(.02,.8)
title("STCA Current/Average Velocity vs. Density")
legend(loc=0)
show()

# %% [markdown]
# ###The plot here looks strikingly similar to that of the CA184 simulation which is good because the logic is essentially the same.  The phase transition is less abrupt here but still occurs at a density around ~.10.  The reason why this plot is more jagged is due to the random slow-downs governed by a probability which I have set to 20% for this particular simulation.  What I have noticed is that by increasing the probability of slowdown the phase transition becomes less and less abrupt.

# %%
fasterSTCAData=array([[  0.02    ,    18.38  ,       0.3676    ],[  0.03    ,    18.38        , 0.5514    ],[  0.04    ,    18.075       , 0.723     ],[  0.05    ,    15.78933333  , 0.78946667],[  0.06    ,    12.78222222  , 0.76693333],[  0.07    ,    11.09333333  , 0.77653333],[  0.08    ,     8.99916667  , 0.71993333],[  0.09    ,     7.58666667  , 0.6828    ],[  0.1     ,     6.74        , 0.674     ],[  0.11    ,     5.6630303   , 0.62293333],[  0.12    ,     4.63166667  , 0.5558    ],[  0.13    ,     4.02153846  , 0.5228    ],[  0.14    ,     3.76571429  , 0.5272    ],[  0.15    ,     3.61333333  , 0.542     ],[  0.16    ,     3.24958333  , 0.51993333],[  0.17     ,    3.12901961 ,  0.53193333],[  0.18     ,    3.01       ,  0.5418    ],[  0.19     ,    2.68421053 ,  0.51      ],[  0.2      ,    2.64566667 ,  0.52913333],[  0.21     ,    2.51968254 ,  0.52913333],[  0.22     ,    2.31333333 ,  0.50893333],[  0.23     ,    2.17217391 ,  0.4996    ],[  0.24     ,    2.17444444 ,  0.52186667],[  0.25     ,    2.0648     ,  0.5162    ],[  0.26     ,    1.94692308 ,  0.5062    ],[  0.27     ,    1.8017284 ,   0.48646667],[  0.28     ,    1.6997619 ,   0.47593333],[  0.29     ,    1.74452381,   0.48846667],[  0.3      ,    1.62311111,   0.48693333],[  0.31     ,    1.58795699 ,  0.49226667],[  0.32     ,    1.45833333 ,  0.46666667],[  0.33     ,    1.4559596  ,  0.48046667],[  0.34     ,    1.32156863 ,  0.44933333],[  0.35     ,    1.32990476 ,  0.46546667],[  0.36     ,    1.23611111 ,  0.445     ],[  0.37     ,    1.18684685 ,  0.43913333],[  0.38     ,    1.13210526 ,  0.4302    ],[  0.39     ,    1.05726496 ,  0.41233333],[  0.4      ,    1.07733333 ,  0.43093333],[  0.41     ,    0.98634146 ,  0.4044    ],[  0.42     ,    0.94825397 ,  0.39826667],[  0.43    ,     0.9427907  ,  0.4054    ],[  0.44    ,     0.91969697 ,  0.40466667],[  0.45    ,     0.87540741 ,  0.39393333],[  0.46    ,     0.80362319 ,  0.36966667],[  0.47    ,     0.79021277 ,  0.3714    ],[  0.48    ,     0.76180556 ,  0.36566667],[  0.49    ,     0.73904762 ,  0.36213333],[  0.5     ,     0.71173333 ,  0.35586667],[  0.51    ,     0.67686275 ,  0.3452    ],[  0.52    ,     0.64371795 ,  0.33473333],[  0.53    ,     0.64691824 ,  0.34286667],[  0.54    ,     0.60962963 ,  0.3292    ],[  0.55    ,     0.59587879 ,  0.32773333],[  0.56     ,    0.55678571 ,  0.3118    ],[  0.57     ,    0.54807018 ,  0.3124    ],[  0.58    ,     0.55684211 ,  0.3174    ],[  0.59     ,    0.48666667 ,  0.28713333],[  0.6      ,    0.46988889 ,  0.28193333]])

# %%
#v_max comparison
plot(fasterSTCAData[:,[0]],fasterSTCAData[:,[1]],'g',lw=1.5,label='Average Velocity (v_max=20)')
plot(fasterSTCAData[:,[0]],fasterSTCAData[:,[2]],'b',lw=1.5,label='Average Current (v_max=20)')
plot(STCAData[:,[0]],STCAData[:,[1]],'k--',lw=1.5,label='Average Velocity (v_max=10)')
plot(STCAData[:,[0]],STCAData[:,[2]],'r--',lw=1.5,label='Average Current (v_max=10)')
xlabel('Density (cars/Length)')
xlim(.02,.6)
title("STCA: Comparing Max Velocities")
legend(loc=0)
show()

# %% [markdown]
# ###Notice how the plots don't match up exactly after the critical density is reached.  This is obviously because of the probability that a car will randomly slow down.  The larger the density, however, the closer the plots match.  Also, the descent from the first phase to the exponentially decaying phase is less abrupt when v_max is larger--consistent with our analysis of the CA184 data.

# %%
ProbSTCAData=array([[ 0.02   ,     9.48333333 , 0.18966667],[ 0.03   ,     8.80888889 , 0.26426667],[ 0.04   ,     9.20333333 , 0.36813333],[ 0.05    ,    8.50666667 , 0.42533333],[ 0.06    ,    8.62666667 , 0.5176    ],[ 0.07   ,     5.12666667 , 0.35886667],[ 0.08    ,    4.48583333 , 0.35886667],[ 0.09    ,    3.42518519 , 0.30826667],[ 0.1     ,    3.56266667 , 0.35626667],[ 0.11    ,    2.80606061 , 0.30866667],[ 0.12    ,    2.44222222 , 0.29306667],[ 0.13    ,    2.33076923 , 0.303     ],[ 0.14    ,    2.3152381  , 0.32413333],[ 0.15    ,    2.11022222 , 0.31653333],[ 0.16    ,    2.14625    , 0.3434    ],[ 0.17    ,    1.97568627 , 0.33586667],[ 0.18    ,    1.72185185 , 0.30993333],[ 0.19    ,    1.66245614 , 0.31586667],[ 0.2     ,    1.533     ,  0.3066    ],[ 0.21    ,    1.36095238,  0.2858    ],[ 0.22    ,    1.37636364,  0.3028    ],[ 0.23    ,    1.39043478,  0.3198    ],[ 0.24    ,    1.13083333,  0.2714    ],[ 0.25    ,    1.18213333,  0.29553333],[ 0.26     ,   1.08846154 , 0.283     ],[ 0.27    ,    1.01679012 , 0.27453333],[ 0.28    ,    0.93857143 , 0.2628    ],[ 0.29    ,    0.94261905 , 0.26393333],[ 0.3     ,    0.90266667 , 0.2708    ],[ 0.31    ,    0.87935484 , 0.2726    ],[ 0.32    ,    0.880625   , 0.2818    ],[ 0.33    ,    0.78383838 , 0.25866667],[ 0.34    ,    0.75117647 , 0.2554    ],[ 0.35    ,    0.72190476 , 0.25266667],[ 0.36    ,    0.71       , 0.2556    ],[ 0.37    ,    0.66720721 , 0.24686667],[ 0.38    ,    0.64280702 , 0.24426667],[ 0.39    ,    0.63384615 , 0.2472    ],[ 0.4     ,    0.59116667 , 0.23646667],[ 0.41    ,    0.5396748  , 0.22126667],[ 0.42    ,    0.56428571 , 0.237     ],[ 0.43    ,    0.53674419 , 0.2308    ],[ 0.44    ,    0.53424242 , 0.23506667],[ 0.45    ,    0.49244444 , 0.2216    ],[ 0.46    ,    0.4673913  , 0.215     ],[ 0.47    ,    0.43787234 , 0.2058    ],[ 0.48    ,    0.44236111 , 0.21233333],[ 0.49    ,    0.42979592 , 0.2106    ],[ 0.5     ,    0.4112   ,   0.2056    ]])

# %%
#Probability comparison
plot(ProbSTCAData[:,[0]],ProbSTCAData[:,[1]],'g',lw=1.5,label='Average Velocity (prob=50%)')
plot(ProbSTCAData[:,[0]],ProbSTCAData[:,[2]],'b',lw=1.5,label='Average Current (prob=50%)')
plot(STCAData[:,[0]],STCAData[:,[1]],'k--',lw=1.5,label='Average Velocity (prob=20%)')
plot(STCAData[:,[0]],STCAData[:,[2]],'r--',lw=1.5,label='Average Current (prob=20%)')
xlabel('Density (cars/Length)')
xlim(.02,.5)
title("STCA: Comparing Probabilities of Slowdown")
legend(loc=0)
show()

# %% [markdown]
# ###It seems like in general if an array of cars have a higher liklihood of slowing down they will do just that--the curves for 50% probability of random slowdown are, in general, more chaotic and just lower than that of its 20% comparison.

# %%
ASEPData=array([[ 0.02    ,    9.74444444 , 0.19488889],[ 0.03     ,   9.97777778 , 0.29933333],[ 0.04    ,    4.48888889 , 0.17955556],[ 0.05    ,    4.32666667 , 0.21633333],[ 0.06    ,    4.36481481 , 0.26188889],[ 0.07    ,    2.54444444 , 0.17811111],[ 0.08    ,    4.56111111 , 0.36488889],[ 0.09    ,    4.22716049 , 0.38044444],[ 0.1     ,    3.78       , 0.378     ],[ 0.11    ,    2.61111111 , 0.28722222],[ 0.12    ,    4.69444444 , 0.56333333],[ 0.13    ,    2.86752137 , 0.37277778],[ 0.14    ,    1.36666667 , 0.19133333],[ 0.15    ,    2.97777778 , 0.44666667],[ 0.16    ,    2.79861111 , 0.44777778],[ 0.17    ,    1.47712418 , 0.25111111],[ 0.18    ,    2.9037037  , 0.52266667],[ 0.19    ,    2.06666667 , 0.39266667],[ 0.2     ,    2.99333333 , 0.59866667],[ 0.21    ,    2.11587302 , 0.44433333],[ 0.22    ,    1.45454545 , 0.32      ],[ 0.23    ,    1.63333333,  0.37566667],[ 0.24     ,   1.44444444,  0.34666667],[ 0.25     ,   2.05555556,  0.51388889],[ 0.26     ,   1.76239316,  0.45822222],[ 0.27    ,    1.52222222 , 0.411     ],[ 0.28    ,    1.78571429 , 0.5       ],[ 0.29    ,    1.83333333 , 0.51333333],[ 0.3     ,    1.43962963 , 0.43188889],[ 0.31    ,    1.76666667 , 0.54766667],[ 0.32    ,    1.3        , 0.416     ],[ 0.33    ,    1.07777778 , 0.35566667],[ 0.34    ,    1.49477124 , 0.50822222],[ 0.35    ,    1.09238095 , 0.38233333],[ 0.36    ,    0.76666667 , 0.276     ],[ 0.37    ,    0.81111111 , 0.30011111],[ 0.38    ,    0.97777778 , 0.37155556],[ 0.39    ,    1.01111111  ,0.39433333],[ 0.4     ,    1.10972222 , 0.44388889],[ 0.41    ,    1.1100271  , 0.45511111],[ 0.42    ,    0.72222222 , 0.30333333],[ 0.43    ,    1.04496124 , 0.44933333],[ 0.44    ,    0.9239899  , 0.40655556],[ 0.45    ,    0.8        , 0.36      ],[ 0.46    ,    0.92270531 , 0.42444444],[ 0.47    ,    0.64444444 , 0.30288889],[ 0.48    ,    0.78773148 , 0.37811111],[ 0.49    ,    0.89614512 , 0.43911111],[ 0.5     ,    0.72222222 , 0.36111111],[ 0.51    ,    0.71111111 , 0.36266667],[ 0.52    ,    0.6        , 0.312     ],[ 0.53    ,    0.63333333 , 0.33566667],[ 0.54    ,    0.60967078 , 0.32922222],[ 0.55    ,    0.47777778 , 0.26277778],[ 0.56    ,    0.65555556 , 0.36711111],[ 0.57    ,    0.6        , 0.342     ],[ 0.58    ,    0.42222222 , 0.24066667],[ 0.59     ,   0.73220339 , 0.432     ],[ 0.6     ,    0.51111111  ,0.30666667],[ 0.61     ,   0.32222222 , 0.19655556],[ 0.62    ,    0.54444444  ,0.33755556],[ 0.63    ,    0.37777778 , 0.238     ],[ 0.64    ,    0.83871528 , 0.53677778],[ 0.65    ,    0.35555556 , 0.23111111]])

# %%
#ASEP density plots
plot(ASEPData[:,[0]],ASEPData[:,[1]],'k',lw=1.5,label='Average Velocity (v_max=10)')
plot(ASEPData[:,[0]],ASEPData[:,[2]],'b',lw=1.5,label='Average Current (v_max=10)')
xlabel('Density (cars/Length)')
xlim(.02,.65)
title("ASEP Average Velocity and Current vs. Density")
legend(loc=0)
show()

# %% [markdown]
# ###First of all--this data is only semi-complete.  This is because the RESNET wireless would bump me off of their server every couple of hours and a density of .65 was the highest I could reach in this time limit.  Second, it seems like the ASEP data is alot more jagged, but still follows the exponentially decaying trend its cousin functions above follow.  There is a phase transition at around a density of ~.04 and again at a density of ~0.14 where the function oscillates wildly around a certain local average.  As the density increases however, the oscillations grow less violent and the curve smooths out especially after a density of .7 (I had a plot up to a density of .8 at one point but I got kicked off of the server before I could save).

# %%
fasterASEPData=array([[  0.02    ,     19.22666667,   0.5453333],[  0.03    ,    19.81333333 ,  0.5944    ],[  0.05    ,     8.46133333 ,  0.42306667],[  0.06    ,     6.13       ,  0.3678    ],[  0.07    ,     4.59142857  , 0.3214    ],[  0.08    ,     4.435       , 0.3548    ],[  0.09    ,     3.43407407 ,  0.30906667],[  0.1     ,     3.39133333 ,  0.33913333],[  0.11     ,    3.34909091 ,  0.3684    ],[  0.12     ,    4.94111111 ,  0.59293333],[  0.13     ,    3.         ,  0.39      ],[  0.14    ,     1.91333333  , 0.26786667],[  0.15     ,    3.38222222 ,  0.50733333],[  0.16    ,     2.88916667  , 0.46226667],[  0.17    ,     2.66980392  , 0.45386667],[  0.18    ,     2.22074074 ,  0.39973333],[  0.19    ,     3.56210526 ,  0.6768    ],[  0.2     ,     1.998      ,  0.3996    ],[  0.21    ,     2.06857143 ,  0.4344    ],[  0.22    ,     1.84575758 ,  0.40606667],[  0.23    ,     2.25652174 ,  0.519     ],[  0.24    ,     1.82       ,  0.4368    ],[  0.25    ,     1.33786667 ,  0.33446667],[  0.26     ,    1.35692308 ,  0.3528    ],[  0.27     ,    1.84       ,  0.4968    ],[  0.28    ,     1.98571429 ,  0.556     ],[  0.29    ,     1.26       ,  0.3528    ],[  0.3     ,     1.82333333 ,  0.547     ],[  0.31     ,    1.38       ,  0.4278    ],[  0.32     ,    1.053125   ,  0.337     ],[  0.33     ,    1.05070707 ,  0.34673333],[  0.34     ,    1.1        ,  0.374]])

# %%
#ASEP v_max comparison
plot(fasterASEPData[:,[0]],fasterASEPData[:,[1]],'g',lw=1.5,label='Average Velocity (v_max=20)')
plot(fasterASEPData[:,[0]],fasterASEPData[:,[2]],'b',lw=1.5,label='Average Current (v_max=20)')
plot(ASEPData[:,[0]],ASEPData[:,[1]],'k--',lw=1.5,label='Average Velocity (v_max=10)')
plot(ASEPData[:,[0]],ASEPData[:,[2]],'r--',lw=1.5,label='Average Current (v_max=10)')
xlabel('Density (cars/Length)')
xlim(.02,.34)
title("ASEP: Comparing Max Velocities")
legend(loc=0)
show()

# %% [markdown]
# ###There is still a rapid drop in current/average velocity around a density of ~.04. and again at ~.14.  The data in the beginning for the higher v_max however is alot smoother and less chaotic which is interesting.

# %%
#THE GUI

import sys

# %%
sys.path.insert(0,"/nfshome/ipowell/JSAnimation")

# %%
from JSAnimation import IPython_display

# %%
v_max = 5
num_cars=4
l=arange(1,31)
XPOS=array([2,6,15,27])
frames=100

X=zeros(frames*num_cars).reshape(frames,num_cars)
X[0]=XPOS

V=X=zeros(frames*num_cars).reshape(frames,num_cars)
V[0]=[1,3,2,4]
                                   

# JSAnimation import available at https://github.com/jakevdp/JSAnimation
from JSAnimation import IPython_display
from matplotlib import animation
# create a simple animation
fig = plt.figure()
ax = plt.axes(xlim=(0, max(l)), ylim=(0, max(l)))
line, = ax.plot([], [], 'r+')

x = l
def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(i*CA184(X,V,l,num_cars), l)
    return i*X,i*V
    

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=100, interval=20, blit=True)
show()
